# %% [markdown]
# ---
# title: "Notebook renderer: local showcase"
# keywords: [browser, notebooks, attributes]
# published: false
# host:
#   route: /examples/notebook
# ---

# %% [markdown]
# # Browser and build rendering
#
# This content is rendered; the surrounding host supplies the CSS. 🙂
#
# :::: {#callout .callout-note title="A host-styled note" data-kind="example"}
# ## Conventional attributes
#
# A [highlighted **span**]{#sample-span .highlight title="Two quoted words" data-action="inspect"}.
#
# ::: {.tip}
# - Nested list item
# - Another item
# :::
#
# Literal syntax stays literal: `::: {.code}`.
# ::::
#
# An inline note.^[An inline explanation.] A reference.[^reference]
#
# [^reference]: A conventional referenced footnote.

# %%
print("ordinary input stays visible")
# Out:
# ordinary input stays visible
# <text is not HTML>

# %%
#| code-fold: true
#| output-fold: show
print("fold me")
# Out:
# Saved output starts open.

# %%
#collapse_input_open
print("legacy initially open")

# %% [markdown]
# ## Attachment
#
# ![Small SVG attachment](attachment:plot.svg)

# %%
#| echo: false
pass

# %%
# %%javascript
# // No saved output: displayed, never executed.
