# %% [markdown]
# # ipynb2web iframe demo
# > A small notebook that demonstrates rendering HTML/JS into an iframe and exposing the exact page source used in that iframe.

# %% [markdown]
# ## Why this sample exists
#
# This notebook is hosted directly in the docs site, so the test page has a stable local notebook URL to convert.
#
# The output below injects a mini HTML+JS page into an iframe and shows that source code in a `<pre>` block.

# %%
# This output intentionally demonstrates iframe srcdoc usage for ipynb2web browser rendering
# Out:
# <div id='iframe-demo' style='font-family: ui-sans-serif,system-ui,sans-serif; border:1px solid #d1d5db; border-radius:10px; padding:12px; background:#f8fafc;'>  <p style='margin:0 0 10px; color:#334155;'><strong>Notebook output demo:</strong> iframe injection + source reveal</p>  <iframe id='demo-frame' style='width:100%; min-height:150px; border:1px solid #cbd5e1; border-radius:8px; background:#fff;'></iframe>  <details style='margin-top:10px;'>    <summary style='cursor:pointer; color:#0f172a; font-weight:600;'>Show iframe HTML + JS source</summary>    <pre id='demo-source' style='margin-top:8px; max-height:260px; overflow:auto; background:#0f172a; color:#e2e8f0; border-radius:8px; padding:10px;'></pre>  </details></div><script>(() => {  const frame = document.getElementById('demo-frame');  const source = document.getElementById('demo-source');  const innerPage = `<!doctype html><html><head><meta charset='utf-8'><style>body{font-family:system-ui,sans-serif;margin:0;padding:16px;bac
# ...
