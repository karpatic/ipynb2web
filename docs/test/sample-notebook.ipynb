# %% [markdown]
# # ipynb2web Demo Notebook
#
# This notebook is intentionally simple and hosted in this repo so `/test/index.html` always has a reliable sample to convert.

# %% [markdown]
# ## What this demonstrates
#
# - A markdown heading
# - A code cell with output
# - A tiny markdown table

# %%
import math
[round(math.sin(i / 5), 4) for i in range(8)]
# Out:
# [0.0, 0.1987, 0.3894, 0.5646, 0.7174, 0.8415, 0.932, 0.9854]

# %% [markdown]
# ### Tiny table
#
# | name | value |
# | --- | ---: |
# | alpha | 1 |
# | beta | 2 |
