# %% [markdown]
# # ipynb2web sample notebook
# > Minimal local sample used by /test/index.html

# %% [markdown]
# ## Demo content
#
# This content comes from the notebook's `content` attribute after conversion.
#
# - markdown works
# - code output works
# - links work: [ipynb2web.com](https://ipynb2web.com/)

# %%
{'status': 'ok', 'message': 'hello from code output'}
# Out:
# {'status': 'ok', 'message': 'hello from code output'}
